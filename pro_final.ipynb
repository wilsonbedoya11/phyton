# %% [markdown]
# <a href="https://colab.research.google.com/github/wilsonbedoya11/phyton/blob/pruebas/pro_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
pagina = pd.read_html('https://datosmacro.expansion.com/estado/gasto/colombia')
pagina[0]

df_datos = pd.DataFrame(pagina[0])
df_datos["Fecha"].max()
# Out:
# 2023

# %%
df_datos.columns
# Out:
# Index(['Fecha', 'G. Público (M.€)', 'Gasto público (M.$)',
#        'Gasto Educación (%Gto Pub)', 'G. Salud (%G. Público Total)',
#        'Gasto Defensa (%Gto Pub)', 'Gasto público (%PIB)',
#        'Gasto público Per Capita', 'Gasto público Per Capita.1'],
#       dtype='object')

# %%
variable = 'Gasto público (M.$)'
dftodos=[df_datos['Gasto público (M.$)'].describe(), df_datos['Gasto Defensa (%Gto Pub)'].describe()]

for i in range(2):
  print(dftodos[i])
  print('\n')  #.to_csv('mi_archivo.csv')
# Out:
# count            42
# unique           42
# top       127.395,1
# freq              1
# Name: Gasto público (M.$), dtype: object
#
#
# count        36
# unique       35
# top       9,94%
# freq          2
# Name: Gasto Defensa (%Gto Pub), dtype: object

# %%
df_datos.shape
# Out:
# (42, 9)

# %%
df_final = pd.concat([df_datos, df_datos])
display(df_final)
# Out:
#     Fecha G. Público (M.€) Gasto público (M.$) Gasto Educación (%Gto Pub)  \
# 0    2023        117.786,1           127.395,1                        NaN
# 1    2022        111.192,4           117.183,1                        NaN
# 2    2021         92.316,9           109.259,5                     11,55%
# 3    2020         79.454,2            90.679,6                     15,69%
# 4    2019         94.870,5           106.216,8                     13,72%
# ..    ...              ...                 ...                        ...
# 37   1986              NaN             6.891,3                        NaN
# 38   1985              NaN             7.136,5                     16,41%
# 39   1984              NaN             8.151,4                     18,09%
# 40   1983              NaN             8.120,9                        NaN
# 41   1982              NaN             8.164,0                        NaN
#
#    G. Salud (%G. Público Total) Gasto Defensa (%Gto Pub) Gasto público (%PIB)  \
# ...
